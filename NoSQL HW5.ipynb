# %%
import pymongo 
import pandas as pd

# %%
from pymongo import MongoClient

# %%
pip install "pymongo[srv]"
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
cluster = MongoClient("mongodb+srv://christinedu:t2PHQTwq9BL481Ip@hw2.s1hfd.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
# Out:
# ---------------------------------------------------------------------------
# LifetimeTimeout                           Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pymongo/srv_resolver.py in _resolve_uri(self, encapsulate_errors)
#      87         try:
# ---> 88             results = _resolve('_' + self.__srv + '._tcp.' + self.__fqdn,
#      89                                'SRV', lifetime=self.__connect_timeout)
#
# /opt/anaconda3/lib/python3.8/site-packages/pymongo/srv_resolver.py in _resolve(*args, **kwargs)
#      40         # dnspython >= 2
# ---> 41         return resolver.resolve(*args, **kwargs)
#      42     # dnspython 1.X
#
# /opt/anaconda3/lib/python3.8/site-packages/dns/resolver.py in resolve(qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
#    1192
# -> 1193     return get_default_resolver().resolve(qname, rdtype, rdclass, tcp, source,
# ...

# %%
db = cluster.sample_supplies

# %%
collection=db.sales

# %%
for i in collection.find({},{'customer.age'}):
    print(i)
# Out:
# {'_id': ObjectId('5bd761dcae323e45a93ccfe8'), 'customer': {'age': 42}}
# {'_id': ObjectId('5bd761dcae323e45a93ccfe9'), 'customer': {'age': 50}}
# {'_id': ObjectId('5bd761dcae323e45a93ccfea'), 'customer': {'age': 51}}
# {'_id': ObjectId('5bd761dcae323e45a93ccfeb'), 'customer': {'age': 45}}
# {'_id': ObjectId('5bd761dcae323e45a93ccfec'), 'customer': {'age': 40}}
# {'_id': ObjectId('5bd761dcae323e45a93ccfed'), 'customer': {'age': 44}}
# {'_id': ObjectId('5bd761dcae323e45a93ccfee'), 'customer': {'age': 40}}
# {'_id': ObjectId('5bd761dcae323e45a93ccfef'), 'customer': {'age': 71}}
# {'_id': ObjectId('5bd761dcae323e45a93ccff0'), 'customer': {'age': 26}}
# {'_id': ObjectId('5bd761dcae323e45a93ccff1'), 'customer': {'age': 57}}
# {'_id': ObjectId('5bd761dcae323e45a93ccff2'), 'customer': {'age': 34}}
# {'_id': ObjectId('5bd761dcae323e45a93ccff3'), 'customer': {'age': 49}}
# {'_id': ObjectId('5bd761dcae323e45a93ccff4'), 'customer': {'age': 59}}
# ...

# %%
db = pd.DataFrame(list(db.sales.find()))

# %%
db
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4995  5bd761deae323e45a93ce36b 2016-01-20 17:29:10.225
# 4996  5bd761deae323e45a93ce36c 2014-11-29 10:09:41.573
# 4997  5bd761deae323e45a93ce36d 2017-12-25 07:02:51.283
# 4998  5bd761deae323e45a93ce36e 2013-12-07 11:06:25.510
# 4999  5bd761deae323e45a93ce36f 2014-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'printer paper', 'tags': ['office', ...        Denver
# 1     [{'name': 'envelopes', 'tags': ['stationary', ...       Seattle
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# ...

# %%
df= pd.concat([db.drop(['customer'], axis=1),
db['customer'].apply(pd.Series)], axis=1)

# %%
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccfe8 2015-03-23 21:06:49.506
# 1     5bd761dcae323e45a93ccfe9 2015-08-25 10:01:02.918
# 2     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 3     5bd761dcae323e45a93ccfeb 2015-02-23 09:53:59.343
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4995  5bd761deae323e45a93ce36b 2016-01-20 17:29:10.225
# 4996  5bd761deae323e45a93ce36c 2014-11-29 10:09:41.573
# 4997  5bd761deae323e45a93ce36d 2017-12-25 07:02:51.283
# 4998  5bd761deae323e45a93ce36e 2013-12-07 11:06:25.510
# 4999  5bd761deae323e45a93ce36f 2014-08-18 06:25:49.739
#
#                                                   items storeLocation  \
# 0     [{'name': 'printer paper', 'tags': ['office', ...        Denver
# 1     [{'name': 'envelopes', 'tags': ['stationary', ...       Seattle
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# ...

# %%
bins=[15,21,26,31,36,41,46,51,56,61,66,71,76]
labels = ['15-20','20-25','25-30','30-35','40-45','45-50','50-55','55-60','60-65','65-70','70-75','75-80']

df['customer.age']=pd.cut(df.age,bins,labels=labels,include_lowest=True)

# %%
import seaborn as sns 

sns.displot(data=df, x='customer.age',kind='hist',color='green',aspect=1.4)
